# %%
print("Addition",1+2)
print("Subtraction",1-2)
print("Multiplication",1*2)
print("Division",1/2)
print("Power",1**2)
print("Modulus",1%2)
print("Floor Division",1//2)
# Out:
# Addition 3
# Subtraction -1
# Multiplication 2
# Division 0.5
# Power 1
# Modulus 1
# Floor Division 0

# %%
A=4
print("A:",A)

A+=4
print(f'New value of A is {A}')

B=5
B-=4
print(f'New value of B is {B}')

C=2
C*=B
print(f'New value of C is {C}')

D=21
D/=C
print(f'New value of D is {D}')

E=2
E**=2
print(f'New value of E is {E}')
# Out:
# A: 4
# New value of A is 8
# New value of B is 1
# New value of C is 2
# New value of D is 10.5
# New value of E is 4

# %%
def basic_list():
    a=[1,2,3,4]
    b=['apple','banana','grapes']
    c=[1,'help',3.14,True]

    print(a),print(b),print(c)

    a=list((12,34,56,'apple',4.5))
    print(a)

    a=[2]*5
    b=[0]*7
    print(a),print(b)

def ListFunctions():
    a=[1,2,3,4]
    print("Original List:",a)

    a.append(5)
    print("Append:",a)

    a.insert(10,0)
    print("Insert:",a)

    a.extend([6,7,8])
    print("Extend:",a)

    a.remove(3)
    print("Remove:",a)

    a.pop()
    print("Pop:",a)

    del a[0]
    print("Regular del:", a)

    del a[0:2]
    print("DEL Slice:", a)

    for items in a:
        print(items,end=' ')

    print()
    matrix=[[1,2,3],[4,5,6],[7,8,9]]
    print("Matrix:",matrix[0][1])

    for row in matrix:
        for column in row:
            print(column,end=' ')

#basic_list()
ListFunctions()
# Out:
# Original List: [1, 2, 3, 4]
# Append: [1, 2, 3, 4, 5]
# Insert: [1, 2, 3, 4, 5, 0]
# Extend: [1, 2, 3, 4, 5, 0, 6, 7, 8]
# Remove: [1, 2, 4, 5, 0, 6, 7, 8]
# Pop: [1, 2, 4, 5, 0, 6, 7]
# Regular del: [2, 4, 5, 0, 6, 7]
# DEL Slice: [5, 0, 6, 7]
# 5 0 6 7
# Matrix: 2
# 1 2 3 4 5 6 7 8 9
